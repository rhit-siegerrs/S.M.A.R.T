# %% [markdown]
# #balancing failure vs success

# %%
from pathlib import Path
# Set working directory and list files to confirm CSV presence
cwd = Path('.').resolve()
print('Working dir:', cwd)
print('Files in notebook dir:')
for p in sorted(Path('.').glob('*'))[:50]:
    print('-', p)
# Out:
# Working dir: /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T
# Files in notebook dir:
# - .git
# - .gitignore
# - README.md
# - SMART_attributes.csv
# - datasets
# - example_data
# - example_data_sandbox_kevin.ipynb
# - failure=1 statistic
# - load_2025-07-01_reduced.ipynb
# - loading_Chengyang.ipynb
# - pre-processing
# - scrape_SMART_attributes.ipynb

# %%
# Install/import libraries and display options
import pandas as pd
from pathlib import Path
pd.set_option('display.max_columns', 200)

# %%
# Path to the CSV we found in the repo
csv_path = Path('example_data/example_Q3_2025/2025-07-01_reduced (balance test).csv')
print('CSV exists:', csv_path.exists())
print('CSV absolute path:', csv_path.resolve())

# Load CSV (adjust encoding/low_memory as needed)
if csv_path.exists():
    df = pd.read_csv(csv_path, encoding='utf-8', low_memory=False)
else:
    df = pd.DataFrame()
    print('CSV not found at the expected location; update `csv_path` to the correct file.')
# Out:
# CSV exists: True
# CSV absolute path: /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/example_data/example_Q3_2025/2025-07-01_reduced (balance test).csv

# %%
# Preview dataset
if not df.empty:
    print('Shape:', df.shape)
    display(df.head())
    print('\nColumns:')
    print(list(df.columns))
    print('\nData types:')
    display(df.dtypes)
    display(df.sample(5))
else:
    print('DataFrame is empty.\n')
# Out:
# Shape: (213459, 197)
#          date serial_number                 model  capacity_bytes  failure  \
# 0  2025-07-01  2207E60CC65A        CT250MX500SSD1    250059350016        0
# 1  2025-07-01  2340E87B92B5        CT250MX500SSD1    250059350016        0
# 2  2025-07-01  2340E87B97E8        CT250MX500SSD1    250059350016        0
# 3  2025-07-01      2EGK64VX  HGST HUH728080ALE604   8001563222016        0
# 4  2025-07-01      2EHZAKAX  HGST HUH728080ALE604   8001563222016        0
#
#   datacenter  cluster_id  vault_id  pod_id  pod_slot_num  is_legacy_format  \
# 0       sac0           0      1028      13           NaN             False
# 1       sac0           0      1028      14           NaN             False
# 2       sac0           0      1028       2           NaN             False
# 3       sac0           0      1028       4          12.0             False
# 4       sac0           0      1028      12          30.0             False
#
#    smart_1_normalized  smart_1_raw  smart_2_normalized  smart_2_raw  \
# 0               100.0          0.0                 NaN          NaN
# 1               100.0          0.0                 NaN          NaN
# 2               100.0          0.0                 NaN          NaN
# 3               100.0          0.0               134.0        104.0
# 4               100.0          0.0               134.0        105.0
#
#    smart_3_normalized  smart_3_raw  smart_4_normalized  smart_4_raw  \
# 0                 NaN          NaN                 NaN          NaN
# 1                 NaN          NaN                 NaN          NaN
# 2                 NaN          NaN                 NaN          NaN
# 3               236.0        113.0               100.0         67.0
# 4               155.0        418.0               100.0         24.0
#
#    smart_5_normalized  smart_5_raw  smart_7_normalized  smart_7_raw  \
# 0               100.0          0.0                 NaN          NaN
# 1               100.0          0.0                 NaN          NaN
# 2               100.0          0.0                 NaN          NaN
# 3               100.0          0.0               100.0          0.0
# 4               100.0          0.0               100.0          0.0
#
#    smart_8_normalized  smart_8_raw  smart_9_normalized  smart_9_raw  \
# 0                 NaN          NaN               100.0      21151.0
# 1                 NaN          NaN               100.0       7720.0
# 2                 NaN          NaN               100.0       2836.0
# 3               128.0         18.0                95.0      36884.0
# 4               128.0         18.0                90.0      75481.0
#
#    smart_10_normalized  smart_10_raw  smart_11_normalized  smart_11_raw  \
# 0                  NaN           NaN                  NaN           NaN
# 1                  NaN           NaN                  NaN           NaN
# 2                  NaN           NaN                  NaN           NaN
# 3                100.0           0.0                  NaN           NaN
# 4                100.0           0.0                  NaN           NaN
#
#    smart_12_normalized  smart_12_raw  smart_13_normalized  smart_13_raw  \
# 0                100.0           3.0                  NaN           NaN
# 1                100.0           6.0                  NaN           NaN
# 2                100.0           2.0                  NaN           NaN
# 3                100.0          62.0                  NaN           NaN
# 4                100.0          19.0                  NaN           NaN
#
#    smart_15_normalized  smart_15_raw  smart_16_normalized  smart_16_raw  \
# 0                  NaN           NaN                  NaN           NaN
# 1                  NaN           NaN                  NaN           NaN
# 2                  NaN           NaN                  NaN           NaN
# 3                  NaN           NaN                  NaN           NaN
# 4                  NaN           NaN                  NaN           NaN
#
#    smart_17_normalized  smart_17_raw  smart_18_normalized  smart_18_raw  \
# 0                  NaN           NaN                  NaN           NaN
# 1                  NaN           NaN                  NaN           NaN
# 2                  NaN           NaN                  NaN           NaN
# 3                  NaN           NaN                  NaN           NaN
# 4                  NaN           NaN                  NaN           NaN
#
#    smart_22_normalized  smart_22_raw  smart_23_normalized  smart_23_raw  \
# 0                  NaN           NaN                  NaN           NaN
# 1                  NaN           NaN                  NaN           NaN
# 2                  NaN           NaN                  NaN           NaN
# 3                100.0         100.0                  NaN           NaN
# 4                 93.0          93.0                  NaN           NaN
#
#    smart_24_normalized  smart_24_raw  smart_27_normalized  smart_27_raw  \
# 0                  NaN           NaN                  NaN           NaN
# 1                  NaN           NaN                  NaN           NaN
# 2                  NaN           NaN                  NaN           NaN
# 3                  NaN           NaN                  NaN           NaN
# 4                  NaN           NaN                  NaN           NaN
#
#    smart_71_normalized  smart_71_raw  smart_82_normalized  smart_82_raw  \
# 0                  NaN           NaN                  NaN           NaN
# 1                  NaN           NaN                  NaN           NaN
# 2                  NaN           NaN                  NaN           NaN
# 3                  NaN           NaN                  NaN           NaN
# 4                  NaN           NaN                  NaN           NaN
#
#    smart_90_normalized  smart_90_raw  smart_160_normalized  smart_160_raw  \
# 0                  NaN           NaN                   NaN            NaN
# 1                  NaN           NaN                   NaN            NaN
# 2                  NaN           NaN                   NaN            NaN
# 3                  NaN           NaN                   NaN            NaN
# 4                  NaN           NaN                   NaN            NaN
#
#    smart_161_normalized  smart_161_raw  smart_163_normalized  smart_163_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_164_normalized  smart_164_raw  smart_165_normalized  smart_165_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_166_normalized  smart_166_raw  smart_167_normalized  smart_167_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_168_normalized  smart_168_raw  smart_169_normalized  smart_169_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_170_normalized  smart_170_raw  smart_171_normalized  smart_171_raw  \
# 0                   NaN            NaN                 100.0            0.0
# 1                   NaN            NaN                 100.0            0.0
# 2                   NaN            NaN                 100.0            0.0
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_172_normalized  smart_172_raw  smart_173_normalized  smart_173_raw  \
# 0                 100.0            0.0                  50.0          654.0
# 1                 100.0            0.0                  84.0          215.0
# 2                 100.0            0.0                  96.0           53.0
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_174_normalized  smart_174_raw  smart_175_normalized  smart_175_raw  \
# 0                 100.0            0.0                   NaN            NaN
# 1                 100.0            0.0                   NaN            NaN
# 2                 100.0            0.0                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_176_normalized  smart_176_raw  smart_177_normalized  smart_177_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_178_normalized  smart_178_raw  smart_179_normalized  smart_179_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_180_normalized  smart_180_raw  smart_181_normalized  smart_181_raw  \
# 0                   0.0           27.0                   NaN            NaN
# 1                   0.0           50.0                   NaN            NaN
# 2                   0.0           51.0                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_182_normalized  smart_182_raw  smart_183_normalized  smart_183_raw  \
# 0                   NaN            NaN                 100.0            0.0
# 1                   NaN            NaN                 100.0            0.0
# 2                   NaN            NaN                 100.0            0.0
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_184_normalized  smart_184_raw  smart_187_normalized  smart_187_raw  \
# 0                 100.0            0.0                 100.0            0.0
# 1                 100.0            0.0                 100.0            0.0
# 2                 100.0            0.0                 100.0            0.0
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_188_normalized  smart_188_raw  smart_189_normalized  smart_189_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_190_normalized  smart_190_raw  smart_191_normalized  smart_191_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_192_normalized  smart_192_raw  smart_193_normalized  smart_193_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                  97.0         4530.0                  97.0         4530.0
# 4                  98.0         2989.0                  98.0         2989.0
#
#    smart_194_normalized  smart_194_raw  smart_195_normalized  smart_195_raw  \
# 0                  74.0           26.0                   NaN            NaN
# 1                  65.0           35.0                   NaN            NaN
# 2                  76.0           24.0                   NaN            NaN
# 3                 253.0           18.0                   NaN            NaN
# 4                 240.0           25.0                   NaN            NaN
#
#    smart_196_normalized  smart_196_raw  smart_197_normalized  smart_197_raw  \
# 0                 100.0            0.0                 100.0            0.0
# 1                 100.0            0.0                 100.0            0.0
# 2                 100.0            0.0                 100.0            0.0
# 3                 100.0            0.0                 100.0            0.0
# 4                 100.0            0.0                 100.0            0.0
#
#    smart_198_normalized  smart_198_raw  smart_199_normalized  smart_199_raw  \
# 0                 100.0            0.0                 100.0            0.0
# 1                 100.0            0.0                 100.0            0.0
# 2                 100.0            0.0                 100.0            0.0
# 3                 100.0            0.0                 200.0            0.0
# 4                 100.0            0.0                 200.0            0.0
#
#    smart_200_normalized  smart_200_raw  smart_201_normalized  smart_201_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_202_normalized  smart_202_raw  smart_206_normalized  smart_206_raw  \
# 0                  50.0           50.0                 100.0            0.0
# 1                  84.0           16.0                 100.0            0.0
# 2                  96.0            4.0                 100.0            0.0
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_210_normalized  smart_210_raw  smart_211_normalized  smart_211_raw  \
# 0                 100.0            0.0                   NaN            NaN
# 1                 100.0            0.0                   NaN            NaN
# 2                 100.0            0.0                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_212_normalized  smart_212_raw  smart_218_normalized  smart_218_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_220_normalized  smart_220_raw  smart_222_normalized  smart_222_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_223_normalized  smart_223_raw  smart_224_normalized  smart_224_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_225_normalized  smart_225_raw  smart_226_normalized  smart_226_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_230_normalized  smart_230_raw  smart_231_normalized  smart_231_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_232_normalized  smart_232_raw  smart_233_normalized  smart_233_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_234_normalized  smart_234_raw  smart_235_normalized  smart_235_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_240_normalized  smart_240_raw  smart_241_normalized  smart_241_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_242_normalized  smart_242_raw  smart_244_normalized  smart_244_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_245_normalized  smart_245_raw  smart_246_normalized  smart_246_raw  \
# 0                   NaN            NaN                 100.0   4.373472e+10
# 1                   NaN            NaN                 100.0   1.513035e+10
# 2                   NaN            NaN                 100.0   5.634706e+09
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_247_normalized  smart_247_raw  smart_248_normalized  smart_248_raw  \
# 0                 100.0   1.184967e+09                 100.0   2.031558e+09
# 1                 100.0   1.792903e+08                 100.0   4.723579e+08
# 2                 100.0   6.771856e+07                 100.0   6.036886e+07
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_250_normalized  smart_250_raw  smart_251_normalized  smart_251_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_252_normalized  smart_252_raw  smart_254_normalized  smart_254_raw  \
# 0                   NaN            NaN                   NaN            NaN
# 1                   NaN            NaN                   NaN            NaN
# 2                   NaN            NaN                   NaN            NaN
# 3                   NaN            NaN                   NaN            NaN
# 4                   NaN            NaN                   NaN            NaN
#
#    smart_255_normalized  smart_255_raw
# 0                   NaN            NaN
# 1                   NaN            NaN
# 2                   NaN            NaN
# 3                   NaN            NaN
# 4                   NaN            NaN
# Columns:
# ['date', 'serial_number', 'model', 'capacity_bytes', 'failure', 'datacenter', 'cluster_id', 'vault_id', 'pod_id', 'pod_slot_num', 'is_legacy_format', 'smart_1_normalized', 'smart_1_raw', 'smart_2_normalized', 'smart_2_raw', 'smart_3_normalized', 'smart_3_raw', 'smart_4_normalized', 'smart_4_raw', 'smart_5_normalized', 'smart_5_raw', 'smart_7_normalized', 'smart_7_raw', 'smart_8_normalized', 'smart_8_raw', 'smart_9_normalized', 'smart_9_raw', 'smart_10_normalized', 'smart_10_raw', 'smart_11_normalized', 'smart_11_raw', 'smart_12_normalized', 'smart_12_raw', 'smart_13_normalized', 'smart_13_raw', 'smart_15_normalized', 'smart_15_raw', 'smart_16_normalized', 'smart_16_raw', 'smart_17_normalized', 'smart_17_raw', 'smart_18_normalized', 'smart_18_raw', 'smart_22_normalized', 'smart_22_raw', 'smart_23_normalized', 'smart_23_raw', 'smart_24_normalized', 'smart_24_raw', 'smart_27_normalized', 'smart_27_raw', 'smart_71_normalized', 'smart_71_raw', 'smart_82_normalized', 'smart_82_raw', 'smart_90_normalized', 'smart_90_raw', 'smart_160_normalized', 'smart_160_raw', 'smart_161_normalized', 'smart_161_raw', 'smart_163_normalized', 'smart_163_raw', 'smart_164_normalized', 'smart_164_raw', 'smart_165_normalized', 'smart_165_raw', 'smart_166_normalized', 'smart_166_raw', 'smart_167_normalized', 'smart_167_raw', 'smart_168_normalized', 'smart_168_raw', 'smart_169_normalized', 'smart_169_raw', 'smart_170_normalized', 'smart_170_raw', 'smart_171_normalized', 'smart_171_raw', 'smart_172_normalized', 'smart_172_raw', 'smart_173_normalized', 'smart_173_raw', 'smart_174_normalized', 'smart_174_raw', 'smart_175_normalized', 'smart_175_raw', 'smart_176_normalized', 'smart_176_raw', 'smart_177_normalized', 'smart_177_raw', 'smart_178_normalized', 'smart_178_raw', 'smart_179_normalized', 'smart_179_raw', 'smart_180_normalized', 'smart_180_raw', 'smart_181_normalized', 'smart_181_raw', 'smart_182_normalized', 'smart_182_raw', 'smart_183_normalized', 'smart_183_raw', 'smart_184_normalized', 'smart_184_raw', 'smart_187_normalized', 'smart_187_raw', 'smart_188_normalized', 'smart_188_raw', 'smart_189_normalized', 'smart_189_raw', 'smart_190_normalized', 'smart_190_raw', 'smart_191_normalized', 'smart_191_raw', 'smart_192_normalized', 'smart_192_raw', 'smart_193_normalized', 'smart_193_raw', 'smart_194_normalized', 'smart_194_raw', 'smart_195_normalized', 'smart_195_raw', 'smart_196_normalized', 'smart_196_raw', 'smart_197_normalized', 'smart_197_raw', 'smart_198_normalized', 'smart_198_raw', 'smart_199_normalized', 'smart_199_raw', 'smart_200_normalized', 'smart_200_raw', 'smart_201_normalized', 'smart_201_raw', 'smart_202_normalized', 'smart_202_raw', 'smart_206_normalized', 'smart_206_raw', 'smart_210_normalized', 'smart_210_raw', 'smart_211_normalized', 'smart_211_raw', 'smart_212_normalized', 'smart_212_raw', 'smart_218_normalized', 'smart_218_raw', 'smart_220_normalized', 'smart_220_raw', 'smart_222_normalized', 'smart_222_raw', 'smart_223_normalized', 'smart_223_raw', 'smart_224_normalized', 'smart_224_raw', 'smart_225_normalized', 'smart_225_raw', 'smart_226_normalized', 'smart_226_raw', 'smart_230_normalized', 'smart_230_raw', 'smart_231_normalized', 'smart_231_raw', 'smart_232_normalized', 'smart_232_raw', 'smart_233_normalized', 'smart_233_raw', 'smart_234_normalized', 'smart_234_raw', 'smart_235_normalized', 'smart_235_raw', 'smart_240_normalized', 'smart_240_raw', 'smart_241_normalized', 'smart_241_raw', 'smart_242_normalized', 'smart_242_raw', 'smart_244_normalized', 'smart_244_raw', 'smart_245_normalized', 'smart_245_raw', 'smart_246_normalized', 'smart_246_raw', 'smart_247_normalized', 'smart_247_raw', 'smart_248_normalized', 'smart_248_raw', 'smart_250_normalized', 'smart_250_raw', 'smart_251_normalized', 'smart_251_raw', 'smart_252_normalized', 'smart_252_raw', 'smart_254_normalized', 'smart_254_raw', 'smart_255_normalized', 'smart_255_raw']
#
# Data types:
# date                     object
# serial_number            object
# model                    object
# capacity_bytes            int64
# failure                   int64
#                          ...
# smart_252_raw           float64
# smart_254_normalized    float64
# smart_254_raw           float64
# smart_255_normalized    float64
# smart_255_raw           float64
# Length: 197, dtype: object
#               date serial_number                model  capacity_bytes  \
# 42416   2025-07-01  40M0A0RDF97G  TOSHIBA MG07ACA14TA  14000519643136
# 11661   2025-07-01      ZA14DRAB         ST8000NM0055   8001563222016
# 200150  2025-07-01  X1K0A06WFVKG  TOSHIBA MG08ACA16TA  16000900661248
# 124024  2025-07-01      ZL219JDG        ST12000NM001G  12000138625024
# 170013  2025-07-01      1PGXKPLT  WDC WUH722222ALE6L4  22000969973760
#
#         failure datacenter  cluster_id  vault_id  pod_id  pod_slot_num  \
# 42416         0       phx1           0      1074       3          19.0
# 11661         0       sac0           0      1040      10           8.0
# 200150        0       sac2          20      3005      10          36.0
# 124024        0       sac2           0      1142       2           8.0
# 170013        0       sac0           0      1183      11          37.0
#
#         is_legacy_format  smart_1_normalized  smart_1_raw  smart_2_normalized  \
# 42416              False               100.0          0.0               100.0
# 11661              False                78.0   69018424.0                 NaN
# 200150             False               100.0          0.0               100.0
# 124024             False                81.0  138725448.0                 NaN
# 170013             False               100.0          0.0               148.0
#
#         smart_2_raw  smart_3_normalized  smart_3_raw  smart_4_normalized  \
# 42416           0.0               100.0       7692.0               100.0
# 11661           NaN                89.0          0.0               100.0
# 200150          0.0               100.0       8053.0               100.0
# 124024          NaN                95.0          0.0               100.0
# 170013         48.0                85.0        339.0               100.0
#
#         smart_4_raw  smart_5_normalized  smart_5_raw  smart_7_normalized  \
# 42416           7.0               100.0          0.0               100.0
# 11661          17.0               100.0          0.0                92.0
# 200150          8.0               100.0          0.0               100.0
# 124024          4.0               100.0          0.0                81.0
# 170013         16.0               100.0          0.0               100.0
#
#          smart_7_raw  smart_8_normalized  smart_8_raw  smart_9_normalized  \
# 42416   0.000000e+00               100.0          0.0                 1.0
# 11661   1.631672e+09                 NaN          NaN                18.0
# 200150  0.000000e+00               100.0          0.0                60.0
# 124024  1.404908e+08                 NaN          NaN                50.0
# 170013  0.000000e+00               140.0         15.0               100.0
#
#         smart_9_raw  smart_10_normalized  smart_10_raw  smart_11_normalized  \
# 42416       42985.0                100.0           0.0                  NaN
# 11661       72575.0                100.0           0.0                  NaN
# 200150      16094.0                100.0           0.0                  NaN
# 124024      43822.0                100.0           0.0                  NaN
# 170013       5492.0                100.0           0.0                  NaN
#
#         smart_11_raw  smart_12_normalized  smart_12_raw  smart_13_normalized  \
# 42416            NaN                100.0           6.0                  NaN
# 11661            NaN                100.0          17.0                  NaN
# 200150           NaN                100.0           8.0                  NaN
# 124024           NaN                100.0           4.0                  NaN
# 170013           NaN                100.0          16.0                  NaN
#
#         smart_13_raw  smart_15_normalized  smart_15_raw  smart_16_normalized  \
# 42416            NaN                  NaN           NaN                  NaN
# 11661            NaN                  NaN           NaN                  NaN
# 200150           NaN                  NaN           NaN                  NaN
# 124024           NaN                  NaN           NaN                  NaN
# 170013           NaN                  NaN           NaN                  NaN
#
#         smart_16_raw  smart_17_normalized  smart_17_raw  smart_18_normalized  \
# 42416            NaN                  NaN           NaN                  NaN
# 11661            NaN                  NaN           NaN                  NaN
# 200150           NaN                  NaN           NaN                  NaN
# 124024           NaN                  NaN           NaN                100.0
# 170013           NaN                  NaN           NaN                  NaN
#
#         smart_18_raw  smart_22_normalized  smart_22_raw  smart_23_normalized  \
# 42416            NaN                  NaN           NaN                100.0
# 11661            NaN                  NaN           NaN                  NaN
# 200150           NaN                  NaN           NaN                100.0
# 124024           0.0                  NaN           NaN                  NaN
# 170013           NaN                100.0     6553700.0                  NaN
#
#         smart_23_raw  smart_24_normalized  smart_24_raw  smart_27_normalized  \
# 42416            0.0                100.0           0.0                  NaN
# 11661            NaN                  NaN           NaN                  NaN
# 200150           0.0                100.0           0.0                  NaN
# 124024           NaN                  NaN           NaN                  NaN
# 170013           NaN                  NaN           NaN                  NaN
#
#         smart_27_raw  smart_71_normalized  smart_71_raw  smart_82_normalized  \
# 42416            NaN                  NaN           NaN                  NaN
# 11661            NaN                  NaN           NaN                  NaN
# 200150           NaN                  NaN           NaN                  NaN
# 124024           NaN                  NaN           NaN                  NaN
# 170013           NaN                100.0           0.0                  NaN
#
#         smart_82_raw  smart_90_normalized  smart_90_raw  smart_160_normalized  \
# 42416            NaN                  NaN           NaN                   NaN
# 11661            NaN                  NaN           NaN                   NaN
# 200150           NaN                  NaN           NaN                   NaN
# 124024           NaN                  NaN           NaN                   NaN
# 170013           NaN                100.0  5.454608e+11                   NaN
#
#         smart_160_raw  smart_161_normalized  smart_161_raw  \
# 42416             NaN                   NaN            NaN
# 11661             NaN                   NaN            NaN
# 200150            NaN                   NaN            NaN
# 124024            NaN                   NaN            NaN
# 170013            NaN                   NaN            NaN
#
#         smart_163_normalized  smart_163_raw  smart_164_normalized  \
# 42416                    NaN            NaN                   NaN
# 11661                    NaN            NaN                   NaN
# 200150                   NaN            NaN                   NaN
# 124024                   NaN            NaN                   NaN
# 170013                   NaN            NaN                   NaN
#
#         smart_164_raw  smart_165_normalized  smart_165_raw  \
# 42416             NaN                   NaN            NaN
# 11661             NaN                   NaN            NaN
# 200150            NaN                   NaN            NaN
# 124024            NaN                   NaN            NaN
# 170013            NaN                   NaN            NaN
#
#         smart_166_normalized  smart_166_raw  smart_167_normalized  \
# 42416                    NaN            NaN                   NaN
# 11661                    NaN            NaN                   NaN
# 200150                   NaN            NaN                   NaN
# 124024                   NaN            NaN                   NaN
# 170013                   NaN            NaN                   NaN
#
#         smart_167_raw  smart_168_normalized  smart_168_raw  \
# 42416             NaN                   NaN            NaN
# 11661             NaN                   NaN            NaN
# 200150            NaN                   NaN            NaN
# 124024            NaN                   NaN            NaN
# 170013            NaN                   NaN            NaN
#
#         smart_169_normalized  smart_169_raw  smart_170_normalized  \
# 42416                    NaN            NaN                   NaN
# 11661                    NaN            NaN                   NaN
# 200150                   NaN            NaN                   NaN
# 124024                   NaN            NaN                   NaN
# 170013                   NaN            NaN                   NaN
#
#         smart_170_raw  smart_171_normalized  smart_171_raw  \
# 42416             NaN                   NaN            NaN
# 11661             NaN                   NaN            NaN
# 200150            NaN                   NaN            NaN
# 124024            NaN                   NaN            NaN
# 170013            NaN                   NaN            NaN
#
#         smart_172_normalized  smart_172_raw  smart_173_normalized  \
# 42416                    NaN            NaN                   NaN
# 11661                    NaN            NaN                   NaN
# 200150                   NaN            NaN                   NaN
# 124024                   NaN            NaN                   NaN
# 170013                   NaN            NaN                   NaN
#
#         smart_173_raw  smart_174_normalized  smart_174_raw  \
# 42416             NaN                   NaN            NaN
# 11661             NaN                   NaN            NaN
# 200150            NaN                   NaN            NaN
# 124024            NaN                   NaN            NaN
# 170013            NaN                   NaN            NaN
#
#         smart_175_normalized  smart_175_raw  smart_176_normalized  \
# 42416                    NaN            NaN                   NaN
# 11661                    NaN            NaN                   NaN
# 200150                   NaN            NaN                   NaN
# 124024                   NaN            NaN                   NaN
# 170013                   NaN            NaN                   NaN
#
#         smart_176_raw  smart_177_normalized  smart_177_raw  \
# 42416             NaN                   NaN            NaN
# 11661             NaN                   NaN            NaN
# 200150            NaN                   NaN            NaN
# 124024            NaN                   NaN            NaN
# 170013            NaN                   NaN            NaN
#
#         smart_178_normalized  smart_178_raw  smart_179_normalized  \
# 42416                    NaN            NaN                   NaN
# 11661                    NaN            NaN                   NaN
# 200150                   NaN            NaN                   NaN
# 124024                   NaN            NaN                   NaN
# 170013                   NaN            NaN                   NaN
#
#         smart_179_raw  smart_180_normalized  smart_180_raw  \
# 42416             NaN                   NaN            NaN
# 11661             NaN                   NaN            NaN
# 200150            NaN                   NaN            NaN
# 124024            NaN                   NaN            NaN
# 170013            NaN                   NaN            NaN
#
#         smart_181_normalized  smart_181_raw  smart_182_normalized  \
# 42416                    NaN            NaN                   NaN
# 11661                    NaN            NaN                   NaN
# 200150                   NaN            NaN                   NaN
# 124024                   NaN            NaN                   NaN
# 170013                   NaN            NaN                   NaN
#
#         smart_182_raw  smart_183_normalized  smart_183_raw  \
# 42416             NaN                   NaN            NaN
# 11661             NaN                   NaN            NaN
# 200150            NaN                   NaN            NaN
# 124024            NaN                   NaN            NaN
# 170013            NaN                   NaN            NaN
#
#         smart_184_normalized  smart_184_raw  smart_187_normalized  \
# 42416                    NaN            NaN                   NaN
# 11661                  100.0            0.0                 100.0
# 200150                   NaN            NaN                   NaN
# 124024                   NaN            NaN                 100.0
# 170013                   NaN            NaN                   NaN
#
#         smart_187_raw  smart_188_normalized  smart_188_raw  \
# 42416             NaN                   NaN            NaN
# 11661             0.0                 100.0            0.0
# 200150            NaN                   NaN            NaN
# 124024            0.0                 100.0            0.0
# 170013            NaN                   NaN            NaN
#
#         smart_189_normalized  smart_189_raw  smart_190_normalized  \
# 42416                    NaN            NaN                   NaN
# 11661                  100.0            0.0                  79.0
# 200150                   NaN            NaN                   NaN
# 124024                   NaN            NaN                  68.0
# 170013                   NaN            NaN                   NaN
#
#         smart_190_raw  smart_191_normalized  smart_191_raw  \
# 42416             NaN                 100.0          515.0
# 11661            21.0                  90.0        20388.0
# 200150            NaN                 100.0           22.0
# 124024           32.0                   NaN            NaN
# 170013            NaN                   NaN            NaN
#
#         smart_192_normalized  smart_192_raw  smart_193_normalized  \
# 42416                  100.0            1.0                 100.0
# 11661                  100.0           51.0                  58.0
# 200150                 100.0            7.0                 100.0
# 124024                 100.0            0.0                  98.0
# 170013                 100.0          243.0                 100.0
#
#         smart_193_raw  smart_194_normalized  smart_194_raw  \
# 42416           211.0                 100.0           30.0
# 11661         84737.0                  21.0           21.0
# 200150           16.0                 100.0           31.0
# 124024         5136.0                  32.0           32.0
# 170013          243.0                  61.0           34.0
#
#         smart_195_normalized  smart_195_raw  smart_196_normalized  \
# 42416                    NaN            NaN                 100.0
# 11661                   78.0     69018424.0                   NaN
# 200150                   NaN            NaN                 100.0
# 124024                   NaN            NaN                   NaN
# 170013                   NaN            NaN                 100.0
#
#         smart_196_raw  smart_197_normalized  smart_197_raw  \
# 42416             0.0                 100.0            0.0
# 11661             NaN                 100.0            0.0
# 200150            0.0                 100.0            0.0
# 124024            NaN                 100.0            0.0
# 170013            0.0                 100.0            0.0
#
#         smart_198_normalized  smart_198_raw  smart_199_normalized  \
# 42416                  100.0            0.0                 200.0
# 11661                  100.0            0.0                 200.0
# 200150                 100.0            0.0                 200.0
# 124024                 100.0            0.0                 200.0
# 170013                 100.0            0.0                 100.0
#
#         smart_199_raw  smart_200_normalized  smart_200_raw  \
# 42416             0.0                   NaN            NaN
# 11661             0.0                   NaN            NaN
# 200150            0.0                   NaN            NaN
# 124024            0.0                 100.0            0.0
# 170013            0.0                   NaN            NaN
#
#         smart_201_normalized  smart_201_raw  smart_202_normalized  \
# 42416                    NaN            NaN                   NaN
# 11661                    NaN            NaN                   NaN
# 200150                   NaN            NaN                   NaN
# 124024                   NaN            NaN                   NaN
# 170013                   NaN            NaN                   NaN
#
#         smart_202_raw  smart_206_normalized  smart_206_raw  \
# 42416             NaN                   NaN            NaN
# 11661             NaN                   NaN            NaN
# 200150            NaN                   NaN            NaN
# 124024            NaN                   NaN            NaN
# 170013            NaN                   NaN            NaN
#
#         smart_210_normalized  smart_210_raw  smart_211_normalized  \
# 42416                    NaN            NaN                   NaN
# 11661                    NaN            NaN                   NaN
# 200150                   NaN            NaN                   NaN
# 124024                   NaN            NaN                   NaN
# 170013                   NaN            NaN                   NaN
#
#         smart_211_raw  smart_212_normalized  smart_212_raw  \
# 42416             NaN                   NaN            NaN
# 11661             NaN                   NaN            NaN
# 200150            NaN                   NaN            NaN
# 124024            NaN                   NaN            NaN
# 170013            NaN                   NaN            NaN
#
#         smart_218_normalized  smart_218_raw  smart_220_normalized  \
# 42416                    NaN            NaN                 100.0
# 11661                    NaN            NaN                   NaN
# 200150                   NaN            NaN                 100.0
# 124024                   NaN            NaN                   NaN
# 170013                   NaN            NaN                   NaN
#
#         smart_220_raw  smart_222_normalized  smart_222_raw  \
# 42416     151650308.0                   1.0        42655.0
# 11661             NaN                   NaN            NaN
# 200150     35782663.0                  61.0        15951.0
# 124024            NaN                   NaN            NaN
# 170013            NaN                   NaN            NaN
#
#         smart_223_normalized  smart_223_raw  smart_224_normalized  \
# 42416                  100.0            0.0                 100.0
# 11661                    NaN            NaN                   NaN
# 200150                 100.0            0.0                 100.0
# 124024                   NaN            NaN                   NaN
# 170013                   NaN            NaN                   NaN
#
#         smart_224_raw  smart_225_normalized  smart_225_raw  \
# 42416             0.0                   NaN            NaN
# 11661             NaN                   NaN            NaN
# 200150            0.0                   NaN            NaN
# 124024            NaN                   NaN            NaN
# 170013            NaN                   NaN            NaN
#
#         smart_226_normalized  smart_226_raw  smart_230_normalized  \
# 42416                  100.0          593.0                   NaN
# 11661                    NaN            NaN                   NaN
# 200150                 100.0          595.0                   NaN
# 124024                   NaN            NaN                   NaN
# 170013                   NaN            NaN                   NaN
#
#         smart_230_raw  smart_231_normalized  smart_231_raw  \
# 42416             NaN                   NaN            NaN
# 11661             NaN                   NaN            NaN
# 200150            NaN                   NaN            NaN
# 124024            NaN                   NaN            NaN
# 170013            NaN                   NaN            NaN
#
#         smart_232_normalized  smart_232_raw  smart_233_normalized  \
# 42416                    NaN            NaN                   NaN
# 11661                    NaN            NaN                   NaN
# 200150                   NaN            NaN                   NaN
# 124024                   NaN            NaN                   NaN
# 170013                   NaN            NaN                   NaN
#
#         smart_233_raw  smart_234_normalized  smart_234_raw  \
# 42416             NaN                   NaN            NaN
# 11661             NaN                   NaN            NaN
# 200150            NaN                   NaN            NaN
# 124024            NaN                   NaN            NaN
# 170013            NaN                   NaN            NaN
#
#         smart_235_normalized  smart_235_raw  smart_240_normalized  \
# 42416                    NaN            NaN                 100.0
# 11661                    NaN            NaN                 100.0
# 200150                   NaN            NaN                 100.0
# 124024                   NaN            NaN                 100.0
# 170013                   NaN            NaN                   NaN
#
#         smart_240_raw  smart_241_normalized  smart_241_raw  \
# 42416             0.0                   NaN            NaN
# 11661         72515.0                 100.0   1.228194e+11
# 200150            0.0                   NaN            NaN
# 124024        43068.0                 100.0   1.380744e+11
# 170013            NaN                   NaN            NaN
#
#         smart_242_normalized  smart_242_raw  smart_244_normalized  \
# 42416                    NaN            NaN                   NaN
# 11661                  100.0   6.513282e+11                   NaN
# 200150                   NaN            NaN                   NaN
# 124024                 100.0   5.527389e+11                   NaN
# 170013                   NaN            NaN                   NaN
#
#         smart_244_raw  smart_245_normalized  smart_245_raw  \
# 42416             NaN                   NaN            NaN
# 11661             NaN                   NaN            NaN
# 200150            NaN                   NaN            NaN
# 124024            NaN                   NaN            NaN
# 170013            NaN                   NaN            NaN
#
#         smart_246_normalized  smart_246_raw  smart_247_normalized  \
# 42416                    NaN            NaN                   NaN
# 11661                    NaN            NaN                   NaN
# 200150                   NaN            NaN                   NaN
# 124024                   NaN            NaN                   NaN
# 170013                   NaN            NaN                   NaN
#
#         smart_247_raw  smart_248_normalized  smart_248_raw  \
# 42416             NaN                   NaN            NaN
# 11661             NaN                   NaN            NaN
# 200150            NaN                   NaN            NaN
# 124024            NaN                   NaN            NaN
# 170013            NaN                   NaN            NaN
#
#         smart_250_normalized  smart_250_raw  smart_251_normalized  \
# 42416                    NaN            NaN                   NaN
# 11661                    NaN            NaN                   NaN
# 200150                   NaN            NaN                   NaN
# 124024                   NaN            NaN                   NaN
# 170013                   NaN            NaN                   NaN
#
#         smart_251_raw  smart_252_normalized  smart_252_raw  \
# 42416             NaN                   NaN            NaN
# 11661             NaN                   NaN            NaN
# 200150            NaN                   NaN            NaN
# 124024            NaN                   NaN            NaN
# 170013            NaN                   NaN            NaN
#
#         smart_254_normalized  smart_254_raw  smart_255_normalized  \
# 42416                    NaN            NaN                   NaN
# 11661                    NaN            NaN                   NaN
# 200150                   NaN            NaN                   NaN
# 124024                   NaN            NaN                   NaN
# 170013                   NaN            NaN                   NaN
#
#         smart_255_raw
# 42416             NaN
# 11661             NaN
# 200150            NaN
# 124024            NaN
# 170013            NaN

# %%
# Normalize column names
if not df.empty:
    df.columns = (
        df.columns
        .astype(str)
        .str.strip()
        .str.lower()
        .str.replace(' ', '_')
        .str.replace('[^0-9a-z_]', '', regex=True)
    )
    print('Normalized columns:')
    print(list(df.columns)[:50])
# Out:
# Normalized columns:
# ['date', 'serial_number', 'model', 'capacity_bytes', 'failure', 'datacenter', 'cluster_id', 'vault_id', 'pod_id', 'pod_slot_num', 'is_legacy_format', 'smart_1_normalized', 'smart_1_raw', 'smart_2_normalized', 'smart_2_raw', 'smart_3_normalized', 'smart_3_raw', 'smart_4_normalized', 'smart_4_raw', 'smart_5_normalized', 'smart_5_raw', 'smart_7_normalized', 'smart_7_raw', 'smart_8_normalized', 'smart_8_raw', 'smart_9_normalized', 'smart_9_raw', 'smart_10_normalized', 'smart_10_raw', 'smart_11_normalized', 'smart_11_raw', 'smart_12_normalized', 'smart_12_raw', 'smart_13_normalized', 'smart_13_raw', 'smart_15_normalized', 'smart_15_raw', 'smart_16_normalized', 'smart_16_raw', 'smart_17_normalized', 'smart_17_raw', 'smart_18_normalized', 'smart_18_raw', 'smart_22_normalized', 'smart_22_raw', 'smart_23_normalized', 'smart_23_raw', 'smart_24_normalized', 'smart_24_raw', 'smart_27_normalized']

# %%
# Missing values summary
if not df.empty:
    missing = df.isna().sum().sort_values(ascending=False)
    display(missing[missing>0].head(50))
# Out:
# smart_164_raw           213459
# smart_160_normalized    213459
# smart_160_raw           213459
# smart_15_raw            213459
# smart_15_normalized     213459
# smart_161_raw           213459
# smart_161_normalized    213459
# smart_163_raw           213459
# smart_163_normalized    213459
# smart_164_normalized    213459
# smart_176_normalized    213459
# smart_251_raw           213459
# smart_251_normalized    213459
# smart_255_raw           213459
# smart_255_normalized    213459
# smart_250_normalized    213459
# smart_250_raw           213459
# smart_176_raw           213459
# smart_178_raw           213459
# smart_178_normalized    213459
# smart_252_raw           213458
# smart_252_normalized    213458
# smart_175_raw           213458
# smart_175_normalized    213458
# smart_212_normalized    213456
# smart_212_raw           213456
# smart_211_normalized    213456
# smart_211_raw           213456
# smart_82_normalized     213454
# smart_82_raw            213454
# smart_225_normalized    213386
# smart_225_raw           213386
# smart_201_raw           213381
# smart_13_raw            213381
# smart_245_raw           213381
# smart_201_normalized    213381
# smart_13_normalized     213381
# smart_245_normalized    213381
# smart_182_raw           213376
# smart_179_raw           213376
# smart_179_normalized    213376
# smart_182_normalized    213376
# smart_181_normalized    213376
# smart_181_raw           213376
# smart_11_raw            213292
# smart_11_normalized     213292
# smart_254_normalized    213256
# smart_254_raw           213256
# smart_165_normalized    213210
# smart_166_normalized    213210
# dtype: int64

# %%
# Convert numeric-like columns where possible
if not df.empty:
    for col in df.columns:
        # try to coerce numeric values
        df[col] = pd.to_numeric(df[col], errors='ignore')
    print('Attempted numeric conversion on object columns.')
# Out:
# Attempted numeric conversion on object columns.
# /tmp/ipykernel_2045736/3186527857.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_numeric(df[col], errors='ignore')

# %%
# Check for common target columns and show class balance if present
possible_targets = ['failure', 'failed', 'target', 'label', 'y', 'is_failed']
found_targets = [c for c in df.columns if c in possible_targets] if not df.empty else []
if found_targets:
    for t in found_targets:
        print('\nTarget column:', t)
        print(df[t].value_counts(dropna=False))
        print(df[t].value_counts(normalize=True, dropna=False))
else:
    print('No common target column names found. Inspect `df.columns` to identify the target.')
# Out:
# Target column: failure
# failure
# 0    213454
# 1         5
# Name: count, dtype: int64
# failure
# 0    0.999977
# 1    0.000023
# Name: proportion, dtype: float64

# %%
# Save cleaned dataframe (if loaded)
if not df.empty:
    out = Path('2025-07-01_reduced_balance_test_cleaned.csv')
    df.to_csv(out, index=False)
    print('Cleaned CSV written to', out.resolve())

# %%
# ROBUST STREAMING & FILTER WORKFLOW
# 1. Counts total rows first (reliable).
# 2. Sets probability to hit target successes.
# 3. Keeps ALL failures as "extra" data on top of the target.

import csv
import random
from pathlib import Path

# --- CONFIGURATION ---
# CHANGE THIS PATH to your real 40GB file location
csv_path = Path('/work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/example_data/example_Q3_2025/balanced_dataset_2025-07-01.csv') 
out_path = Path('balanced_dataset_final.csv')

target_successes = 20_000   # We aim for this many WORKING drives
possible_targets = ['failure','failed','target','label','y','is_failed']
random_seed = 42
progress_interval = 500_000

random.seed(random_seed)

# --- HELPER FUNCTION ---
def find_target_idx(header):
    lower = [h.strip().lower() for h in header]
    for t in possible_targets:
        if t in lower:
            return lower.index(t)
    for i, h in enumerate(lower):
        if 'failure' in h or 'fail' == h:
            return i
    return None

if not csv_path.exists():
    raise FileNotFoundError(f'CSV not found: {csv_path}')

# --- PASS 1: COUNT TOTAL ROWS ---
print("Pass 1: Counting total rows...")
with csv_path.open(newline='', encoding='utf-8', errors='replace') as f:
    # Subtract 1 for header
    total_rows = sum(1 for _ in f) - 1

print(f"Total rows found: {total_rows}")

# --- CALCULATION ---
# We ignore failure count here. We just want to downsample the WHOLE file 
# enough to get roughly 'target_successes' amount of normal data.
if total_rows <= target_successes:
    keep_prob = 1.0
else:
    keep_prob = target_successes / total_rows

print(f"Sampling Probability: {keep_prob:.6f}")
print(f"Expected Successes: ~{target_successes}")
print(f"Expected Failures: ALL of them (added on top)")

# --- PASS 2: FILTER & SAVE ---
print("Pass 2: Streaming and filtering...")
kept_failures = 0
kept_successes = 0
rows_seen = 0

with csv_path.open(newline='', encoding='utf-8', errors='replace') as fin, \
     out_path.open('w', newline='', encoding='utf-8') as fout:
    
    reader = csv.reader(fin)
    writer = csv.writer(fout)
    
    # Write Header
    header = next(reader)
    writer.writerow(header)
    
    # Locate Target Column
    target_idx = find_target_idx(header)
    if target_idx is None:
        raise ValueError("Could not find 'failure' column in header.")

    for row in reader:
        rows_seen += 1
        
        # Safety check for ragged rows
        if len(row) <= target_idx:
            continue
            
        val = row[target_idx].strip()
        
        # Check if Failure (1) or Success (0)
        try:
            v = int(float(val))
        except:
            v = 1 if val.lower() in ('true','t','yes','y','1') else 0
            
        if v == 1:
            # RULE 1: KEEP ALL FAILURES
            writer.writerow(row)
            kept_failures += 1
        else:
            # RULE 2: RANDOMLY SAMPLE SUCCESSES
            if random.random() < keep_prob:
                writer.writerow(row)
                kept_successes += 1
        
        if rows_seen % progress_interval == 0:
            print(f"Processed {rows_seen} rows...")

print("--- DONE ---")
print(f"Total Processed: {rows_seen}")
print(f"Failures Kept:   {kept_failures} (100%)")
print(f"Successes Kept:  {kept_successes}")
print(f"Final Dataset:   {kept_failures + kept_successes} rows")
print(f"Saved to: {out_path.resolve()}")
# Out:
# Pass 1: Counting total rows...
# Total rows found: 99736
# Sampling Probability: 0.200529
# Expected Successes: ~20000
# Expected Failures: ALL of them (added on top)
# Pass 2: Streaming and filtering...
# --- DONE ---
# Total Processed: 99736
# Failures Kept:   5 (100%)
# Successes Kept:  20145
# Final Dataset:   20150 rows
# Saved to: /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/example_data/example_Q3_2025/balanced_dataset_final.csv
