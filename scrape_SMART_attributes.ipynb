# %%
# Scrape SMART attributes from a Wikipedia table and output then as .csv.
# This will be used to map SMART attribute IDs to their names and descriptions.
# Written by Kevin Cotellesso
import pandas as pd
import requests

# %%
# Scrape SMART attributes
url = 'https://en.wikipedia.org/wiki/Self-Monitoring,_Analysis_and_Reporting_Technology'
headers = {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:146.0) Gecko/20100101 Firefox/146.0'}
response = requests.get(url, headers=headers)

# %%
# Parse the HTML response
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')
print(f"Response status code: {response.status_code}")
# Out:
# Response status code: 200

# %%
# Find the SMART attributes table
# The table is usually titled "Known ATA S.M.A.R.T. attributes"
tables = soup.find_all('table', class_='wikitable')
print(f"Found {len(tables)} wikitable(s)")

# Extract the main SMART attributes table (usually the first one)
if tables:
    smart_table = tables[1]
    df = pd.read_html(str(smart_table))[0]
    print(f"\nTable shape: {df.shape}")
    print(f"\nColumns: {df.columns.tolist()}")
    print(f"\nFirst few rows:")
    display(df.head(10))
# Out:
# Found 5 wikitable(s)
#
# Table shape: (89, 5)
#
# Columns: ['ID', 'Attribute name', 'Ideal', '!', 'Description']
#
# First few rows:
# /tmp/ipykernel_107522/2532758852.py:9: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(smart_table))[0]
#         ID             Attribute name   Ideal             !  \
# 0  01 0x01            Read Error Rate     Low           NaN
# 1  02 0x02     Throughput Performance    High           NaN
# 2  03 0x03               Spin-Up Time     Low           NaN
# 3  04 0x04           Start/Stop Count     NaN           NaN
# 4  05 0x05  Reallocated Sectors Count     Low  [33][34][35]
# 5  06 0x06        Read Channel Margin     NaN           NaN
# 6  07 0x07            Seek Error Rate  Varies           NaN
# 7  08 0x08      Seek Time Performance    High           NaN
# 8  09 0x09             Power-On Hours     NaN           NaN
# 9  10 0x0A           Spin Retry Count     Low          [42]
#
#                                          Description
# 0  (Vendor specific raw value.) Stores data relat...
# 1  Overall (general) throughput performance of a ...
# 2  Average time of spindle spin up (from zero RPM...
# 3  A tally of spindle start/stop cycles. The spin...
# 4  Count of reallocated sectors. The raw value re...
# 5  Margin of a channel while reading data. The fu...
# 6  (Vendor specific raw value.) Rate of seek erro...
# 7  Average performance of seek operations of the ...
# 8  Count of hours in power-on state. The raw valu...
# 9  Count of retry of spin start attempts. This at...

# %%
# Clean up the data a little. Get rid of the ! column and turn the ID into an integer.
df = df.drop(columns=['!'])
df['ID'] = df['ID'].str.split(" ").str[0].astype(int)
print(f"\nCleaned DataFrame shape: {df.shape}")
display(df.head(10))
# Out:
# Cleaned DataFrame shape: (89, 4)
#    ID             Attribute name   Ideal  \
# 0   1            Read Error Rate     Low
# 1   2     Throughput Performance    High
# 2   3               Spin-Up Time     Low
# 3   4           Start/Stop Count     NaN
# 4   5  Reallocated Sectors Count     Low
# 5   6        Read Channel Margin     NaN
# 6   7            Seek Error Rate  Varies
# 7   8      Seek Time Performance    High
# 8   9             Power-On Hours     NaN
# 9  10           Spin Retry Count     Low
#
#                                          Description
# 0  (Vendor specific raw value.) Stores data relat...
# 1  Overall (general) throughput performance of a ...
# 2  Average time of spindle spin up (from zero RPM...
# 3  A tally of spindle start/stop cycles. The spin...
# 4  Count of reallocated sectors. The raw value re...
# 5  Margin of a channel while reading data. The fu...
# 6  (Vendor specific raw value.) Rate of seek erro...
# 7  Average performance of seek operations of the ...
# 8  Count of hours in power-on state. The raw valu...
# 9  Count of retry of spin start attempts. This at...

# %%
# Clean the data and save to CSV
# Remove any multi-level column headers if present
if isinstance(df.columns, pd.MultiIndex):
    df.columns = ['_'.join(col).strip() for col in df.columns.values]

# Save to CSV
output_path = 'SMART_attributes.csv'
df.to_csv(output_path, index=False)
print(f"\nSaved SMART attributes to: {output_path}")
print(f"Total attributes: {len(df)}")
# Out:
# Saved SMART attributes to: SMART_attributes.csv
# Total attributes: 89
