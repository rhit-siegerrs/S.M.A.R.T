# %%
from pathlib import Path
import pandas as pd
from concurrent.futures import ProcessPoolExecutor, as_completed
import os
from collections import Counter

base_dir = Path("/work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets")

folders = [
    # 22 - 25
    base_dir / "data_Q4_2022", base_dir / "data_Q4_2023", base_dir / "data_Q4_2024",
    base_dir / "data_Q3_2024", base_dir / "data_Q3_2025", base_dir / "data_Q3_2023", base_dir / "data_Q3_2022",
    base_dir / "data_Q2_2022", base_dir / "data_Q2_2023", base_dir / "data_Q2_2024", base_dir / "data_Q2_2025",
    base_dir / "data_Q1_2022", base_dir / "data_Q1_2023", base_dir / "data_Q1_2024", base_dir / "data_Q1_2025",

    # 16 - 21
    base_dir / "data_Q4_2016", base_dir / "data_Q4_2017", base_dir / "data_Q4_2018",
    base_dir / "data_Q4_2019", base_dir / "data_Q4_2020", base_dir / "data_Q4_2021",
    base_dir / "data_Q3_2016", base_dir / "data_Q3_2017", base_dir / "data_Q3_2018",
    base_dir / "data_Q3_2019", base_dir / "data_Q3_2020", base_dir / "data_Q3_2021",
    base_dir / "data_Q2_2016", base_dir / "data_Q2_2017", base_dir / "data_Q2_2018",
    base_dir / "data_Q2_2019", base_dir / "data_Q2_2020", base_dir / "data_Q2_2021",
    base_dir / "data_Q1_2016", base_dir / "data_Q1_2017", base_dir / "data_Q1_2018",
    base_dir / "data_Q1_2019", base_dir / "data_Q1_2020", base_dir / "data_Q1_2021",

    # 13 - 15
    base_dir / "data_2013" / "2013",
    base_dir / "data_2014" / "2014",
    base_dir / "data_2015" / "2015",
]

def count_models(csv_path):
    try:
        s = pd.read_csv(
            csv_path,
            usecols=["model"],
            encoding="latin1",      # 关键：不用默认utf-8
            low_memory=False
        )["model"]
        vc = s.value_counts()
        return vc.to_dict(), int(vc.sum())
    except Exception as e:
        return {"__ERROR__": f"{csv_path} -> {e}"}, 0


# 收集所有CSV
csv_files = []
for folder in folders:
    files = list(folder.rglob("*.csv"))
    print(f"{folder}: {len(files)} files")
    csv_files.extend(files)

print("Total CSV files:", len(csv_files))

# 使用一半CPU核
total_cores = os.cpu_count()
half_cores = max(1, total_cores // 2)
print(f"CPU cores: {total_cores}, Using: {half_cores}")

global_counter = Counter()
total_rows = 0
errors = []

with ProcessPoolExecutor(max_workers=half_cores) as exe:
    futures = [exe.submit(count_models, str(f)) for f in csv_files]
    for fut in as_completed(futures):
        d, n = fut.result()
        total_rows += n
        if "__ERROR__" in d:
            errors.append(d["__ERROR__"])
        else:
            global_counter.update(d)

# 生成统计表
stats = (
    pd.Series(global_counter, name="count")
      .sort_values(ascending=False)
      .to_frame()
)
stats["ratio"] = stats["count"] / total_rows
stats["ratio_percent"] = stats["ratio"] * 100

print("Total samples:", total_rows)
print(stats.head(20))

out_file = "model_distribution_all_years_streaming.csv"
stats.to_csv(out_file)
print("Saved to:", out_file)

if errors:
    print(f"\n[WARN] {len(errors)} files failed. First 5 errors:")
    for e in errors[:5]:
        print(e)
# Out:
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q4_2022: 92 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q4_2023: 92 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q4_2024: 92 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q3_2024: 92 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q3_2025: 92 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q3_2023: 92 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q3_2022: 92 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q2_2022: 91 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q2_2023: 91 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q2_2024: 91 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q2_2025: 91 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q1_2022: 90 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q1_2023: 90 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q1_2024: 91 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q1_2025: 90 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q4_2016: 92 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q4_2017: 92 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q4_2018: 92 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q4_2019: 92 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q4_2020: 92 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q4_2021: 92 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q3_2016: 92 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q3_2017: 92 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q3_2018: 92 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q3_2019: 92 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q3_2020: 92 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q3_2021: 92 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q2_2016: 91 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q2_2017: 91 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q2_2018: 91 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q2_2019: 91 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q2_2020: 91 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q2_2021: 91 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q1_2016: 91 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q1_2017: 90 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q1_2018: 90 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q1_2019: 90 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q1_2020: 91 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_Q1_2021: 90 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_2013/2013: 266 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_2014/2014: 365 files
# /work/shibberu/share/MA384_Data_Mining_Projects_Winter_2025-26/SMART_failure_prediction/S.M.A.R.T/datasets/data_2015/2015: 365 files
# Total CSV files: 4557
# CPU cores: 256, Using: 128
# Total samples: 651018495
#                             count     ratio  ratio_percent
# ST4000DM000              80454439  0.123582      12.358242
# TOSHIBA MG07ACA14TA      68245826  0.104829      10.482932
# ST8000NM0055             42736967  0.065646       6.564632
# HGST HMS5C4040BLE640     41156102  0.063218       6.321802
# ST12000NM0008            39632553  0.060878       6.087777
# ST16000NM001G            37817926  0.058090       5.809040
# ST12000NM0007            37147796  0.057061       5.706105
# ST8000DM002              31658329  0.048629       4.862892
# TOSHIBA MG08ACA16TA      30687263  0.047137       4.713731
# HGST HUH721212ALN604     25143580  0.038622       3.862191
# WDC WUH721816ALE6L4      23552287  0.036178       3.617760
# ST12000NM001G            22706260  0.034878       3.487806
# HGST HUH721212ALE604     21613689  0.033200       3.319981
# ST14000NM001G            18113014  0.027823       2.782258
# HGST HMS5C4040ALE640     16789193  0.025789       2.578912
# WDC WUH721414ALE6L4      14688314  0.022562       2.256205
# WDC WUH722222ALE6L4      14533863  0.022325       2.232481
# TOSHIBA MG08ACA16TE       8422214  0.012937       1.293698
# TOSHIBA MG08ACA16TEY      7151157  0.010985       1.098457
# Hitachi HDS5C3030ALA630   6641559  0.010202       1.020180
# Saved to: model_distribution_all_years_streaming.csv
